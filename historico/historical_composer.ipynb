# %%
# !ls -r | grep "csv" > csv.txt

# %%
with open('csv.txt', 'r') as f:
    lista = [str(line.strip()) for line in f]
csv_list = lista[1:-1]

# %%
import pandas as pd
import numpy as np
import re
import os
import sys
import time
import os
import glob
from pathlib import Path
os.path.abspath('')
path = os.path.abspath('')
timestr = time.strftime("%Y%m%d")
timestr = timestr 
def alerta(list):
    #Si no hay ningun falso -> mensaje positivo
    if all(list): print (mensaje_pos)
    else: print (mensaje_neg)
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
# print(result)

# %%
folder = ''
extension = '.csv'
default_cols = ["MALLA",
"ID POZO",
"DIAMETRO PLG",
"CARGA FONDO DISENO", 
"KG FONDO DISENO", 
"AIRE FONDO DISENO", 
"CARGA COLUMNA  DISENO",
"KG COLUMNA DISENO",
"AIRE INTERMEDIO DISENO", 
"GRAVILLA INTERMEDIO DISENO", 
"AIRE SUPERIOR DISENO",
"TACO GRAVILLA DISENO", 
"SECUENCIA DETONACION DISENO",
"PROFUNDIDAD REAL",
"CARGA FONDO REAL", 
"KG FONDO REAL", 
"AIRE FONDO REAL", 
"CARGA COLUMNA REAL",
"KG COLUMNA REAL",
"AIRE INTERMEDIO REAL", 
"GRAVILLA INTERMEDIO REAL", 
"AIRE SUPERIOR REAL",
"TACO GRAVILLA REAL", 
"SECUENCIA DETONACION REAL",
"AGUA"]
default_cols[3] = default_cols[3].replace('CARGA FONDO DISENO', 'CARGA FONDO DISENO ')
default_cols[4] = default_cols[4].replace('KG FONDO DISENO', 'KG FONDO DISENO ')
default_cols[5] = default_cols[5].replace('AIRE FONDO DISENO', 'AIRE FONDO DISENO ')
default_cols[8] = default_cols[8].replace('AIRE INTERMEDIO DISENO', 'AIRE INTERMEDIO DISENO ')
default_cols[9] = default_cols[9].replace('GRAVILLA INTERMEDIO DISENO', 'GRAVILLA INTERMEDIO DISENO ')
default_cols[11] = default_cols[11].replace('TACO GRAVILLA DISENO', 'TACO GRAVILLA DISENO ')
default_cols[14] = default_cols[14].replace('CARGA FONDO REAL', 'CARGA FONDO REAL ')
default_cols[15] = default_cols[15].replace('KG FONDO REAL', 'KG FONDO REAL ')
default_cols[16] = default_cols[16].replace('AIRE FONDO REAL', 'AIRE FONDO REAL ')
default_cols[19] = default_cols[19].replace('AIRE INTERMEDIO REAL', 'AIRE INTERMEDIO REAL ')
default_cols[20] = default_cols[20].replace('GRAVILLA INTERMEDIO REAL', 'GRAVILLA INTERMEDIO REAL ')
default_cols[22] = default_cols[22].replace('TACO GRAVILLA REAL', 'TACO GRAVILLA REAL ')

# %%
for file_name in csv_list:
    final_name = folder+file_name
    print('Cargando el archivo '+final_name+'...')
    data = pd.read_csv(folder+file_name, header=0)
    df = data.copy()
    required_cols = ['MALLA', 'ID POZO', 'DIAMETRO PLG']
    #Fondo
    fondo_diseno = ['CARGA FONDO DISENO ', 'KG FONDO DISENO ']
    fondo_real = ['CARGA FONDO REAL ', 'KG FONDO REAL ']
    #Diseno
    columna_diseno = ['CARGA COLUMNA  DISENO', 'KG COLUMNA DISENO']
    columna_real = ['CARGA COLUMNA REAL', 'KG COLUMNA REAL']


    necessary_cols_in_csv = []

    if set(required_cols) <= set(default_cols) and (
    (set(fondo_diseno) <= set(default_cols) and set(fondo_real) <= set(default_cols)) or
    (set(columna_diseno) <= set(default_cols) and set(columna_real) <= set(default_cols))    
    ): print ("El archivo SI contiene las columnas necesarias")
    else: 
        print ("El archivo NO contiene las columnas necesarias")

    #imprimir cols necesarias:
    print('De las columnas obligatorias, el archivo: ')
    if set(required_cols) <= set(default_cols): print ('Contiene: ' + ' '.join(required_cols))
    else: print ('No contiene: ' + ''.join(required_cols))

    if (set(fondo_diseno) <= set(default_cols) and set(fondo_real) <= set(default_cols)): print ('Contiene: ' + ' '.join(fondo_diseno) + ' '.join(fondo_real))
    else: print ('No contiene: ' + ' '.join(fondo_diseno) + ' '.join(fondo_real))

    if (set(columna_diseno) <= set(default_cols) and set(columna_real) <= set(default_cols)): print ('Contiene: ' + ' '.join(columna_diseno) + ' '.join(columna_real))
    else: print ('No contiene: ' + ' '.join(columna_diseno) + ' '.join(columna_real))


    #Crear lista de columnas necesarias que si tiene el archvo:
    if set(required_cols) <= set(default_cols): necessary_cols_in_csv.extend(required_cols)
    if (set(fondo_diseno) <= set(default_cols) and set(fondo_real) <= set(default_cols)): necessary_cols_in_csv.extend(fondo_diseno+fondo_real)
    if (set(columna_diseno) <= set(default_cols) and set(columna_real) <= set(default_cols)): necessary_cols_in_csv.extend(columna_diseno+columna_real)


    #Armar la lista de [valores required_cols] + [explisvo real] +  [explosivo planificado]


    # ### Explosivo caso 1: Carga de Fondo

    # Conservar solo las que son posibles de cargar con explosivos de fondo o mas
    fondo_cols = ['CARGA FONDO DISENO ','KG FONDO DISENO ','CARGA FONDO REAL ','KG FONDO REAL ']
    

    df_fondo_ready = df.dropna(subset=['CARGA FONDO DISENO ','KG FONDO DISENO ','CARGA FONDO REAL ','KG FONDO REAL '])
    df_fondo_ready[fondo_cols].head(5)


    # ### Explosivo caso 2: Carga de Columna

    # Conservar solo las que son posibles de cargar con explosivos de columna o mas
    columna_cols = ['CARGA COLUMNA  DISENO','KG COLUMNA DISENO','CARGA COLUMNA REAL','KG COLUMNA REAL']
    df_columna_ready = df.dropna(subset=['CARGA COLUMNA  DISENO','KG COLUMNA DISENO','CARGA COLUMNA REAL','KG COLUMNA REAL'])
    (df_columna_ready[columna_cols]).head(5)
    # df_columna_ready.to_csv('columna' + ".csv", index=False)


    # ### Explosivo caso 3: Carga de Fondo y Columna
    cols = fondo_cols+columna_cols
    df_both_explosives = df.dropna(subset=['CARGA COLUMNA  DISENO',
                                           'KG COLUMNA DISENO',
                                           'CARGA COLUMNA REAL',
                                           'KG COLUMNA REAL',
                                           'CARGA FONDO DISENO ',
                                           'KG FONDO DISENO ',
                                           'CARGA FONDO REAL ',
                                           'KG FONDO REAL '])
    df_both_explosives[cols].head(5)


    # ### Consolidación explosivos
    #Valido pero solo con fondo
    df_only_fondo = pd.concat([df_fondo_ready,df_both_explosives]).drop_duplicates(keep=False)
    #Valido pero solo con columna
    df_only_columna = pd.concat([df_columna_ready,df_both_explosives]).drop_duplicates(keep=False)
    filtered_aux = pd.concat([df_only_columna,df_only_fondo])
    filtered_df = pd.concat([filtered_aux,df_both_explosives])
    # filtered_df.to_csv(timestr + ".csv", index=False)
    df_not_ready = pd.concat([df,filtered_df]).drop_duplicates(keep=False)
    # df_not_ready = union[union.isnull().any(axis=1)]
    # not_ready_name = "NoParaCargar" + timestr
    # df_not_ready.to_csv(not_ready_name + ".csv", index=False)
    # df_len = int(len(df))
    # filtered_len = int(len(filtered_df))
    # outer_len = int(len(df_not_ready))
    # print(df_len)
    # print(filtered_len)
    # print(outer_len)


    # Comprobar si el archivo contiene el número total de columnas que podría tener:

    # ## Tratamiento de Mallas
    df = filtered_df.copy()
    df['MALLA']
    print("Comprobando si el nombre de las mallas contiene prefijo válido:")
    #Comprobar que el prefijo sea el correcto:
    check = []
    mensaje_neg = "-> ERROR!, El nombre de las mallas NO cumple el formato de prefijos"
    mensaje_pos = "-> BIEN!, El nombre de las mallas SI cumple el formato de prefijos"

    #lista de prefijos:
    # prefix_mallas = ['MAF07-R1', 'MAF09-SE', 'MAF10-N', 'MAF11-W', 'MAF9-SE','MAF7']

    # for m in range(0, len(df['MALLA'])):
    #     malla_contiene_prefijo = any(prefix_mallas in df['MALLA'][0] for prefix_mallas in prefix_mallas)
    #     check.append(malla_contiene_prefijo)
    # alerta(check)
    print('Revisando si existen mallas con sufijo "_vm":')
    suffix = '_vm'
#     suffix_count = sum(1 for s in df['MALLA'] if s.endswith(suffix))
#     print ('-> Se han econtrado '+ str(suffix_count)+' mallas con sufijo "_vm"')


    # ## Tratamiento de pozos
    #Identificador de Pozo en la malla de perforacion
    print('Revisando identificador de pozo en la malla de perforación:')
    id_pozo = pd.to_numeric(df['ID POZO'], errors='coerce')
    print ('-> Existen '+ str(id_pozo.isna().sum()) + ' pozos que no podrán ser importador por ser AUX o vacio')
    df_id_pozo = df.dropna(subset=['ID POZO'])
    df_id_pozo['ID POZO'] = list(map(str, df_id_pozo['ID POZO']))
    # df_id_pozo = df[~df['ID POZO'].contains("AUX")]
    # df_id_pozo['ID POZO']
    df_id_pozo['ID POZO']


    # ## Formato de valores 
    df = df_id_pozo.copy()
    print('Asegurando exactitud valores numericos:')
    df['DIAMETRO PLG'] = np.around(list(map(float, df['DIAMETRO PLG'])),5)
    df['GRAVILLA INTERMEDIO DISENO '] = np.around(list(map(float, df['GRAVILLA INTERMEDIO DISENO '])),5)
#     df['AIRE INTERMEDIO REAL '] = np.around(list(map(float, df['AIRE INTERMEDIO REAL '])),5)
#     df['TACO GRAVILLA REAL '] = np.around(list(map(float, df['TACO GRAVILLA REAL '])),5)
    # data['DIAMETRO PLG']
    print ('Asegurando formato de valores ...')
    print ('1. Asegurando columnas formato texto:')
    df['MALLA'] = list(map(str, df['MALLA']))
    df['CARGA FONDO DISENOlo '] = list(map(str, df['CARGA FONDO DISENO ']))
    df['CARGA COLUMNA  DISENO'] = list(map(str, df['CARGA COLUMNA  DISENO']))
    df['CARGA FONDO REAL '] = list(map(str, df['CARGA FONDO REAL ']))
    df['CARGA COLUMNA REAL'] = list(map(str, df['CARGA COLUMNA REAL']))
    print ('-> Formato texto asegurado')
    print ('2. Asegurando columnas formato numero:')
    # df['ID POZO'] = list(map(float, df['ID POZO']))
    # df['DIAMETRO PLG'] = list(map(float, df['DIAMETRO PLG']))
    df['KG FONDO DISENO '] = list(map(float, df['KG FONDO DISENO ']))
#     df['AIRE FONDO DISENO '] = list(map(float, df['AIRE FONDO DISENO ']))
    df['KG COLUMNA DISENO'] = list(map(float, df['KG COLUMNA DISENO']))
#     df['AIRE FONDO DISENO '] = list(map(float, df['AIRE FONDO DISENO ']))
    df['AIRE SUPERIOR DISENO'] = list(map(float, df['AIRE SUPERIOR DISENO']))
    df['TACO GRAVILLA DISENO '] = list(map(float, df['TACO GRAVILLA DISENO ']))
    df['SECUENCIA DETONACION DISENO'] = list(map(float, df['SECUENCIA DETONACION DISENO']))
#     df['PROFUNDIDAD REAL'] = list(map(float, df['PROFUNDIDAD REAL']))
#     df['KG FONDO REAL '] = list(map(float, df['KG FONDO REAL ']))
#     df['AIRE FONDO REAL '] = list(map(float, df['AIRE FONDO REAL ']))
    df['KG COLUMNA REAL'] = list(map(float, df['KG COLUMNA REAL']))
    df['AIRE SUPERIOR REAL'] = list(map(float, df['AIRE SUPERIOR REAL']))
    df['SECUENCIA DETONACION REAL'] = list(map(float, df['SECUENCIA DETONACION REAL']))
#     df['AGUA'] = list(map(float, df['AGUA']))
    print ('-> Formato numérico asegurado')
    print ('Comprobando información mínima de carga:')
    print ('Existen '+ str(len(df['MALLA']))+' mallas válidas')
    print ('Existen '+ str(len(df['ID POZO']))+' id_pozo válidos')
    print ('Existen '+ str(len(df['DIAMETRO PLG']))+' diámetros PGL válidos')


    # ## Exportación
    path_name = "out/"+file_name.replace(".csv",'')
    export_dir = path_name+"/"
    Path(export_dir).mkdir(parents=True, exist_ok=True)    
    export_name = 'Valid-' + file_name.replace(".csv",'')
    df.to_csv(export_dir+export_name + ".csv", index=False)
    print ('Archivo válido exportado: ' + export_name)
    not_ready_name = "Invalid-" + file_name.replace(".csv",'')
    df_not_ready.to_csv(export_dir+not_ready_name + ".csv", index=False)
    print ('Archivo NO válido exportado: ' + not_ready_name)
# Out:
# Cargando el archivo 31.12.20 MAF10-N-3260-11-C.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 9 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 113 mallas válidas
# Existen 113 id_pozo válidos
# Existen 113 diámetros PGL válidos
# Archivo válido exportado: Valid-31.12.20 MAF10-N-3260-11-C
# Archivo NO válido exportado: Invalid-31.12.20 MAF10-N-3260-11-C
# Cargando el archivo 31.08.19 MAF7-R1-2795-05-08-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 284 mallas válidas
# Existen 284 id_pozo válidos
# Existen 284 diámetros PGL válidos
# Archivo válido exportado: Valid-31.08.19 MAF7-R1-2795-05-08-A
# Archivo NO válido exportado: Invalid-31.08.19 MAF7-R1-2795-05-08-A
# Cargando el archivo 31.07.20 MAF11-W-3680-02-04-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 192 mallas válidas
# Existen 192 id_pozo válidos
# Existen 192 diámetros PGL válidos
# Archivo válido exportado: Valid-31.07.20 MAF11-W-3680-02-04-B
# Archivo NO válido exportado: Invalid-31.07.20 MAF11-W-3680-02-04-B
# Cargando el archivo 31.01.21 MAF10-N-3245-03-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 183 mallas válidas
# Existen 183 id_pozo válidos
# Existen 183 diámetros PGL válidos
# Archivo válido exportado: Valid-31.01.21 MAF10-N-3245-03-60-A
# Archivo NO válido exportado: Invalid-31.01.21 MAF10-N-3245-03-60-A
# Cargando el archivo 31.01.19 MAF9-SE-3515-05-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 99 mallas válidas
# Existen 99 id_pozo válidos
# Existen 99 diámetros PGL válidos
# Archivo válido exportado: Valid-31.01.19 MAF9-SE-3515-05-A
# Archivo NO válido exportado: Invalid-31.01.19 MAF9-SE-3515-05-A
# Cargando el archivo 31.01.19 MAF11-W-3875-01-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 78 mallas válidas
# Existen 78 id_pozo válidos
# Existen 78 diámetros PGL válidos
# Archivo válido exportado: Valid-31.01.19 MAF11-W-3875-01-A
# Archivo NO válido exportado: Invalid-31.01.19 MAF11-W-3875-01-A
# Cargando el archivo 30.12.19 MAF11-W-3755-02-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 60 mallas válidas
# Existen 60 id_pozo válidos
# Existen 60 diámetros PGL válidos
# Archivo válido exportado: Valid-30.12.19 MAF11-W-3755-02-B
# Archivo NO válido exportado: Invalid-30.12.19 MAF11-W-3755-02-B
# Cargando el archivo 30.12.19 MAF10-N-3365-23-25-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 95 mallas válidas
# Existen 95 id_pozo válidos
# Existen 95 diámetros PGL válidos
# Archivo válido exportado: Valid-30.12.19 MAF10-N-3365-23-25-A
# Archivo NO válido exportado: Invalid-30.12.19 MAF10-N-3365-23-25-A
# Cargando el archivo 30.10.20 MAF9-SE-3350-05-06-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 352 mallas válidas
# Existen 352 id_pozo válidos
# Existen 352 diámetros PGL válidos
# Archivo válido exportado: Valid-30.10.20 MAF9-SE-3350-05-06-A
# Archivo NO válido exportado: Invalid-30.10.20 MAF9-SE-3350-05-06-A
# Cargando el archivo 30.09.19 MAF11-W-3875-01-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 1 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 297 mallas válidas
# Existen 297 id_pozo válidos
# Existen 297 diámetros PGL válidos
# Archivo válido exportado: Valid-30.09.19 MAF11-W-3875-01-A
# Archivo NO válido exportado: Invalid-30.09.19 MAF11-W-3875-01-A
# Cargando el archivo 30.08.20 MAF10-N-3290-05-06-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 149 mallas válidas
# Existen 149 id_pozo válidos
# Existen 149 diámetros PGL válidos
# Archivo válido exportado: Valid-30.08.20 MAF10-N-3290-05-06-A
# Archivo NO válido exportado: Invalid-30.08.20 MAF10-N-3290-05-06-A
# Cargando el archivo 30.07.20 MAF10-N-3305-02-11-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 2 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 204 mallas válidas
# Existen 204 id_pozo válidos
# Existen 204 diámetros PGL válidos
# Archivo válido exportado: Valid-30.07.20 MAF10-N-3305-02-11-A
# Archivo NO válido exportado: Invalid-30.07.20 MAF10-N-3305-02-11-A
# Cargando el archivo 30.04.20 MAF10-N-3305-02-04-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 1 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 199 mallas válidas
# Existen 199 id_pozo válidos
# Existen 199 diámetros PGL válidos
# Archivo válido exportado: Valid-30.04.20 MAF10-N-3305-02-04-A
# Archivo NO válido exportado: Invalid-30.04.20 MAF10-N-3305-02-04-A
# Cargando el archivo 30.03.19 MAF10-N-3380-01-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 132 mallas válidas
# Existen 132 id_pozo válidos
# Existen 132 diámetros PGL válidos
# Archivo válido exportado: Valid-30.03.19 MAF10-N-3380-01-A
# Archivo NO válido exportado: Invalid-30.03.19 MAF10-N-3380-01-A
# Cargando el archivo 30.01.21 MAF9-SE-3320-04-05-06-61-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 158 mallas válidas
# Existen 158 id_pozo válidos
# Existen 158 diámetros PGL válidos
# Archivo válido exportado: Valid-30.01.21 MAF9-SE-3320-04-05-06-61-A
# Archivo NO válido exportado: Invalid-30.01.21 MAF9-SE-3320-04-05-06-61-A
# Cargando el archivo 29.12.2020 MAF7-R1-2750-03-05-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 181 mallas válidas
# Existen 181 id_pozo válidos
# Existen 181 diámetros PGL válidos
# Archivo válido exportado: Valid-29.12.2020 MAF7-R1-2750-03-05-A
# Archivo NO válido exportado: Invalid-29.12.2020 MAF7-R1-2750-03-05-A
# Cargando el archivo 29.12.19 MAF9-SE-3425-03-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 308 mallas válidas
# Existen 308 id_pozo válidos
# Existen 308 diámetros PGL válidos
# Archivo válido exportado: Valid-29.12.19 MAF9-SE-3425-03-B
# Archivo NO válido exportado: Invalid-29.12.19 MAF9-SE-3425-03-B
# Cargando el archivo 29.11.2020 MAF9-SE-3335-08-09-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 2 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 278 mallas válidas
# Existen 278 id_pozo válidos
# Existen 278 diámetros PGL válidos
# Archivo válido exportado: Valid-29.11.2020 MAF9-SE-3335-08-09-A
# Archivo NO válido exportado: Invalid-29.11.2020 MAF9-SE-3335-08-09-A
# Cargando el archivo 29.11.19 MAF11-W-3770-01-02-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 189 mallas válidas
# Existen 189 id_pozo válidos
# Existen 189 diámetros PGL válidos
# Archivo válido exportado: Valid-29.11.19 MAF11-W-3770-01-02-B
# Archivo NO válido exportado: Invalid-29.11.19 MAF11-W-3770-01-02-B
# Cargando el archivo 29.11.19 MAF10-N-3350-03-06-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 404 mallas válidas
# Existen 404 id_pozo válidos
# Existen 404 diámetros PGL válidos
# Archivo válido exportado: Valid-29.11.19 MAF10-N-3350-03-06-60-A
# Archivo NO válido exportado: Invalid-29.11.19 MAF10-N-3350-03-06-60-A
# Cargando el archivo 29.11.19 MAF10-N-08-10-12-13-22-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 195 mallas válidas
# Existen 195 id_pozo válidos
# Existen 195 diámetros PGL válidos
# Archivo válido exportado: Valid-29.11.19 MAF10-N-08-10-12-13-22-A
# Archivo NO válido exportado: Invalid-29.11.19 MAF10-N-08-10-12-13-22-A
# Cargando el archivo 29.09.20 MAF9-SE-3365-13-15-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 251 mallas válidas
# Existen 251 id_pozo válidos
# Existen 251 diámetros PGL válidos
# Archivo válido exportado: Valid-29.09.20 MAF9-SE-3365-13-15-A
# Archivo NO válido exportado: Invalid-29.09.20 MAF9-SE-3365-13-15-A
# Cargando el archivo 29.08.20 MAF11-W-3665-05-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 168 mallas válidas
# Existen 168 id_pozo válidos
# Existen 168 diámetros PGL válidos
# Archivo válido exportado: Valid-29.08.20 MAF11-W-3665-05-A
# Archivo NO válido exportado: Invalid-29.08.20 MAF11-W-3665-05-A
# Cargando el archivo 29.07.20 MAF9-SE-3365-01-08-11-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 1 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 141 mallas válidas
# Existen 141 id_pozo válidos
# Existen 141 diámetros PGL válidos
# Archivo válido exportado: Valid-29.07.20 MAF9-SE-3365-01-08-11-A
# Archivo NO válido exportado: Invalid-29.07.20 MAF9-SE-3365-01-08-11-A
# Cargando el archivo 29.04.19 MAF9-SE-3470-01-02-03-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 503 mallas válidas
# Existen 503 id_pozo válidos
# Existen 503 diámetros PGL válidos
# Archivo válido exportado: Valid-29.04.19 MAF9-SE-3470-01-02-03-A
# Archivo NO válido exportado: Invalid-29.04.19 MAF9-SE-3470-01-02-03-A
# Cargando el archivo 29.01.21 MAF11-W-3620-04-07-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 16 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 153 mallas válidas
# Existen 153 id_pozo válidos
# Existen 153 diámetros PGL válidos
# Archivo válido exportado: Valid-29.01.21 MAF11-W-3620-04-07-A
# Archivo NO válido exportado: Invalid-29.01.21 MAF11-W-3620-04-07-A
# Cargando el archivo 28.12.20 MAF10-N-3260-07-08-09-10-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 1 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 264 mallas válidas
# Existen 264 id_pozo válidos
# Existen 264 diámetros PGL válidos
# Archivo válido exportado: Valid-28.12.20 MAF10-N-3260-07-08-09-10-A
# Archivo NO válido exportado: Invalid-28.12.20 MAF10-N-3260-07-08-09-10-A
# Cargando el archivo 28.11.20 MAF7-R1-2757-02-05-06-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 271 mallas válidas
# Existen 271 id_pozo válidos
# Existen 271 diámetros PGL válidos
# Archivo válido exportado: Valid-28.11.20 MAF7-R1-2757-02-05-06-B
# Archivo NO válido exportado: Invalid-28.11.20 MAF7-R1-2757-02-05-06-B
# Cargando el archivo 28.11.20 MAF10-N-3290-07-11-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 178 mallas válidas
# Existen 178 id_pozo válidos
# Existen 178 diámetros PGL válidos
# Archivo válido exportado: Valid-28.11.20 MAF10-N-3290-07-11-A
# Archivo NO válido exportado: Invalid-28.11.20 MAF10-N-3290-07-11-A
# Cargando el archivo 28.11.19 MAF9-SE-3425-05-06-07-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 615 mallas válidas
# Existen 615 id_pozo válidos
# Existen 615 diámetros PGL válidos
# Archivo válido exportado: Valid-28.11.19 MAF9-SE-3425-05-06-07-A
# Archivo NO válido exportado: Invalid-28.11.19 MAF9-SE-3425-05-06-07-A
# Cargando el archivo 28.10.20 MAF11-W-3620-02-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 197 mallas válidas
# Existen 197 id_pozo válidos
# Existen 197 diámetros PGL válidos
# Archivo válido exportado: Valid-28.10.20 MAF11-W-3620-02-A
# Archivo NO válido exportado: Invalid-28.10.20 MAF11-W-3620-02-A
# Cargando el archivo 28.09.20 MAF7-R1-2765-02-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 2 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 207 mallas válidas
# Existen 207 id_pozo válidos
# Existen 207 diámetros PGL válidos
# Archivo válido exportado: Valid-28.09.20 MAF7-R1-2765-02-60-A
# Archivo NO válido exportado: Invalid-28.09.20 MAF7-R1-2765-02-60-A
# Cargando el archivo 28.08.20 MAF7-R1-2772-01-04-06-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 299 mallas válidas
# Existen 299 id_pozo válidos
# Existen 299 diámetros PGL válidos
# Archivo válido exportado: Valid-28.08.20 MAF7-R1-2772-01-04-06-60-A
# Archivo NO válido exportado: Invalid-28.08.20 MAF7-R1-2772-01-04-06-60-A
# Cargando el archivo 28.07.19 MAF11-W-3815-01-02-04-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 4 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 316 mallas válidas
# Existen 316 id_pozo válidos
# Existen 316 diámetros PGL válidos
# Archivo válido exportado: Valid-28.07.19 MAF11-W-3815-01-02-04-A
# Archivo NO válido exportado: Invalid-28.07.19 MAF11-W-3815-01-02-04-A
# Cargando el archivo 28.06.20 MAF11-W-3680-01-02-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 1 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 224 mallas válidas
# Existen 224 id_pozo válidos
# Existen 224 diámetros PGL válidos
# Archivo válido exportado: Valid-28.06.20 MAF11-W-3680-01-02-A
# Archivo NO válido exportado: Invalid-28.06.20 MAF11-W-3680-01-02-A
# Cargando el archivo 28.05.19 MAF9-SE-3470-03-05-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 798 mallas válidas
# Existen 798 id_pozo válidos
# Existen 798 diámetros PGL válidos
# Archivo válido exportado: Valid-28.05.19 MAF9-SE-3470-03-05-A
# Archivo NO válido exportado: Invalid-28.05.19 MAF9-SE-3470-03-05-A
# Cargando el archivo 28.02.21 MAF9-SE-3320-09-10-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 2 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 218 mallas válidas
# Existen 218 id_pozo válidos
# Existen 218 diámetros PGL válidos
# Archivo válido exportado: Valid-28.02.21 MAF9-SE-3320-09-10-A
# Archivo NO válido exportado: Invalid-28.02.21 MAF9-SE-3320-09-10-A
# Cargando el archivo 28.02.20 MAF11-W-3710-02-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 8 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 172 mallas válidas
# Existen 172 id_pozo válidos
# Existen 172 diámetros PGL válidos
# Archivo válido exportado: Valid-28.02.20 MAF11-W-3710-02-A
# Archivo NO válido exportado: Invalid-28.02.20 MAF11-W-3710-02-A
# Cargando el archivo 28.01.19 MAF10-N-3410-02-07-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 164 mallas válidas
# Existen 164 id_pozo válidos
# Existen 164 diámetros PGL válidos
# Archivo válido exportado: Valid-28.01.19 MAF10-N-3410-02-07-A
# Archivo NO válido exportado: Invalid-28.01.19 MAF10-N-3410-02-07-A
# Cargando el archivo 27.12.20 MAF11-W-3620-02-04-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 115 mallas válidas
# Existen 115 id_pozo válidos
# Existen 115 diámetros PGL válidos
# Archivo válido exportado: Valid-27.12.20 MAF11-W-3620-02-04-60-A
# Archivo NO válido exportado: Invalid-27.12.20 MAF11-W-3620-02-04-60-A
# Cargando el archivo 27.10.2020 MAF10-N-3305-21-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 88 mallas válidas
# Existen 88 id_pozo válidos
# Existen 88 diámetros PGL válidos
# Archivo válido exportado: Valid-27.10.2020 MAF10-N-3305-21-A
# Archivo NO válido exportado: Invalid-27.10.2020 MAF10-N-3305-21-A
# Cargando el archivo 27.08.20 MAF9-SE-3380-03-06-07-08-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 2 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 421 mallas válidas
# Existen 421 id_pozo válidos
# Existen 421 diámetros PGL válidos
# Archivo válido exportado: Valid-27.08.20 MAF9-SE-3380-03-06-07-08-A
# Archivo NO válido exportado: Invalid-27.08.20 MAF9-SE-3380-03-06-07-08-A
# Cargando el archivo 27.08.19 MAF10-N-3395-24-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 177 mallas válidas
# Existen 177 id_pozo válidos
# Existen 177 diámetros PGL válidos
# Archivo válido exportado: Valid-27.08.19 MAF10-N-3395-24-A
# Archivo NO válido exportado: Invalid-27.08.19 MAF10-N-3395-24-A
# Cargando el archivo 27.07.19 MAF10-N-3395-01-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 5 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 333 mallas válidas
# Existen 333 id_pozo válidos
# Existen 333 diámetros PGL válidos
# Archivo válido exportado: Valid-27.07.19 MAF10-N-3395-01-60-A
# Archivo NO válido exportado: Invalid-27.07.19 MAF10-N-3395-01-60-A
# Cargando el archivo 27.06.20 MAF10-N-3305-11-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 303 mallas válidas
# Existen 303 id_pozo válidos
# Existen 303 diámetros PGL válidos
# Archivo válido exportado: Valid-27.06.20 MAF10-N-3305-11-A
# Archivo NO válido exportado: Invalid-27.06.20 MAF10-N-3305-11-A
# Cargando el archivo 27.06.19 MAF11-W-3815-01-02-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 7 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# ...
# Existen 220 mallas válidas
# Existen 220 id_pozo válidos
# Existen 220 diámetros PGL válidos
# Archivo válido exportado: Valid-02.03.19 MAF7-R1-2810-02-B
# Archivo NO válido exportado: Invalid-02.03.19 MAF7-R1-2810-02-B
# Cargando el archivo 02.02.20 MAF10N-3335-02-06-D.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 373 mallas válidas
# Existen 373 id_pozo válidos
# Existen 373 diámetros PGL válidos
# Archivo válido exportado: Valid-02.02.20 MAF10N-3335-02-06-D
# Archivo NO válido exportado: Invalid-02.02.20 MAF10N-3335-02-06-D
# Cargando el archivo 02.01.21 MAF7-R1-2750-03-05-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 169 mallas válidas
# Existen 169 id_pozo válidos
# Existen 169 diámetros PGL válidos
# Archivo válido exportado: Valid-02.01.21 MAF7-R1-2750-03-05-B
# Archivo NO válido exportado: Invalid-02.01.21 MAF7-R1-2750-03-05-B
# Cargando el archivo 02.01.20 MAF11-W-3740-01-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 103 mallas válidas
# Existen 103 id_pozo válidos
# Existen 103 diámetros PGL válidos
# Archivo válido exportado: Valid-02.01.20 MAF11-W-3740-01-A
# Archivo NO válido exportado: Invalid-02.01.20 MAF11-W-3740-01-A
# Cargando el archivo 02.01.19 MAF10-E-3440-01-C.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 245 mallas válidas
# Existen 245 id_pozo válidos
# Existen 245 diámetros PGL válidos
# Archivo válido exportado: Valid-02.01.19 MAF10-E-3440-01-C
# Archivo NO válido exportado: Invalid-02.01.19 MAF10-E-3440-01-C
# Cargando el archivo 01.12.2020 MAF10-N-3260-07-08-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 276 mallas válidas
# Existen 276 id_pozo válidos
# Existen 276 diámetros PGL válidos
# Archivo válido exportado: Valid-01.12.2020 MAF10-N-3260-07-08-A
# Archivo NO válido exportado: Invalid-01.12.2020 MAF10-N-3260-07-08-A
# Cargando el archivo 01.11.20 MAF10-N-3275-06-11-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 265 mallas válidas
# Existen 265 id_pozo válidos
# Existen 265 diámetros PGL válidos
# Archivo válido exportado: Valid-01.11.20 MAF10-N-3275-06-11-60-A
# Archivo NO válido exportado: Invalid-01.11.20 MAF10-N-3275-06-11-60-A
# Cargando el archivo 01.10.20 MAF11-W-3650-01-60-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 167 mallas válidas
# Existen 167 id_pozo válidos
# Existen 167 diámetros PGL válidos
# Archivo válido exportado: Valid-01.10.20 MAF11-W-3650-01-60-B
# Archivo NO válido exportado: Invalid-01.10.20 MAF11-W-3650-01-60-B
# Cargando el archivo 01.10.20 MAF10-N-3275-05-06-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 180 mallas válidas
# Existen 180 id_pozo válidos
# Existen 180 diámetros PGL válidos
# Archivo válido exportado: Valid-01.10.20 MAF10-N-3275-05-06-A
# Archivo NO válido exportado: Invalid-01.10.20 MAF10-N-3275-05-06-A
# Cargando el archivo 01.06.20 MAF7-R1-2780-2P-02-03-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 373 mallas válidas
# Existen 373 id_pozo válidos
# Existen 373 diámetros PGL válidos
# Archivo válido exportado: Valid-01.06.20 MAF7-R1-2780-2P-02-03-A
# Archivo NO válido exportado: Invalid-01.06.20 MAF7-R1-2780-2P-02-03-A
# Cargando el archivo 01.05.20 MAF9-SE-3710-01-02-60-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 250 mallas válidas
# Existen 250 id_pozo válidos
# Existen 250 diámetros PGL válidos
# Archivo válido exportado: Valid-01.05.20 MAF9-SE-3710-01-02-60-A
# Archivo NO válido exportado: Invalid-01.05.20 MAF9-SE-3710-01-02-60-A
# Cargando el archivo 01.05.19 MAF10-N-3425-06-11-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 314 mallas válidas
# Existen 314 id_pozo válidos
# Existen 314 diámetros PGL válidos
# Archivo válido exportado: Valid-01.05.19 MAF10-N-3425-06-11-A
# Archivo NO válido exportado: Invalid-01.05.19 MAF10-N-3425-06-11-A
# Cargando el archivo 01.04.20 MAF10-N-3305-01-02-A.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 360 mallas válidas
# Existen 360 id_pozo válidos
# Existen 360 diámetros PGL válidos
# Archivo válido exportado: Valid-01.04.20 MAF10-N-3305-01-02-A
# Archivo NO válido exportado: Invalid-01.04.20 MAF10-N-3305-01-02-A
# Cargando el archivo 01.04.19 MAF7-R1-2810-07-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 0 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 123 mallas válidas
# Existen 123 id_pozo válidos
# Existen 123 diámetros PGL válidos
# Archivo válido exportado: Valid-01.04.19 MAF7-R1-2810-07-B
# Archivo NO válido exportado: Invalid-01.04.19 MAF7-R1-2810-07-B
# Cargando el archivo 01.03.21 MAF9-SE-3305-06-B.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 1 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 136 mallas válidas
# Existen 136 id_pozo válidos
# Existen 136 diámetros PGL válidos
# Archivo válido exportado: Valid-01.03.21 MAF9-SE-3305-06-B
# Archivo NO válido exportado: Invalid-01.03.21 MAF9-SE-3305-06-B
# Cargando el archivo 01.03.20 MAF9-SE-3410-02-C.csv...
# El archivo SI contiene las columnas necesarias
# De las columnas obligatorias, el archivo:
# Contiene: MALLA ID POZO DIAMETRO PLG
# Contiene: CARGA FONDO DISENO  KG FONDO DISENO CARGA FONDO REAL  KG FONDO REAL
# Contiene: CARGA COLUMNA  DISENO KG COLUMNA DISENOCARGA COLUMNA REAL KG COLUMNA REAL
# Comprobando si el nombre de las mallas contiene prefijo válido:
# Revisando si existen mallas con sufijo "_vm":
# Revisando identificador de pozo en la malla de perforación:
# -> Existen 4 pozos que no podrán ser importador por ser AUX o vacio
# Asegurando exactitud valores numericos:
# Asegurando formato de valores ...
# 1. Asegurando columnas formato texto:
# -> Formato texto asegurado
# 2. Asegurando columnas formato numero:
# -> Formato numérico asegurado
# Comprobando información mínima de carga:
# Existen 296 mallas válidas
# Existen 296 id_pozo válidos
# Existen 296 diámetros PGL válidos
# Archivo válido exportado: Valid-01.03.20 MAF9-SE-3410-02-C
# Archivo NO válido exportado: Invalid-01.03.20 MAF9-SE-3410-02-C
